# %%
import pandas as pd
import pm4py
print(pm4py.__version__)
# Out:
# 2.7.15.2

# %%
tracking_data_away_df = pd.read_csv('sample-data\data\Sample_Game_1\Sample_Game_1_RawTrackingData_Away_Team.csv', skiprows=2)
print('Tracking data away:')
print(tracking_data_away_df.columns)
display(tracking_data_away_df.head())
tracking_data_home_df = pd.read_csv('sample-data\data\Sample_Game_1\Sample_Game_1_RawTrackingData_Home_Team.csv', skiprows=2)
print('Tracking data home:')
print(tracking_data_home_df.columns)
display(tracking_data_home_df.head())
# Out:
# Tracking data away:
# Index(['Period', 'Frame', 'Time [s]', 'Player25', 'Unnamed: 4', 'Player15',
#        'Unnamed: 6', 'Player16', 'Unnamed: 8', 'Player17', 'Unnamed: 10',
#        'Player18', 'Unnamed: 12', 'Player19', 'Unnamed: 14', 'Player20',
#        'Unnamed: 16', 'Player21', 'Unnamed: 18', 'Player22', 'Unnamed: 20',
#        'Player23', 'Unnamed: 22', 'Player24', 'Unnamed: 24', 'Player26',
#        'Unnamed: 26', 'Player27', 'Unnamed: 28', 'Player28', 'Unnamed: 30',
#        'Ball', 'Unnamed: 32'],
#       dtype='object')
#    Period  Frame  Time [s]  Player25  Unnamed: 4  Player15  Unnamed: 6  \
# 0       1      1      0.04   0.90509     0.47462   0.58393     0.20794
# 1       1      2      0.08   0.90494     0.47462   0.58393     0.20794
# 2       1      3      0.12   0.90434     0.47463   0.58393     0.20794
# 3       1      4      0.16   0.90377     0.47463   0.58351     0.20868
# 4       1      5      0.20   0.90324     0.47464   0.58291     0.21039
#
#    Player16  Unnamed: 8  Player17  ...  Player24  Unnamed: 24  Player26  \
# 0   0.67658     0.46710   0.67310  ...   0.37833      0.27383       NaN
# 1   0.67658     0.46710   0.67310  ...   0.37833      0.27383       NaN
# 2   0.67658     0.46710   0.67310  ...   0.37833      0.27383       NaN
# 3   0.67640     0.46762   0.67279  ...   0.37756      0.27473       NaN
# 4   0.67599     0.46769   0.67253  ...   0.37663      0.27543       NaN
#
#    Unnamed: 26  Player27  Unnamed: 28  Player28  Unnamed: 30     Ball  \
# 0          NaN       NaN          NaN       NaN          NaN  0.45472
# 1          NaN       NaN          NaN       NaN          NaN  0.49645
# 2          NaN       NaN          NaN       NaN          NaN  0.53716
# 3          NaN       NaN          NaN       NaN          NaN  0.55346
# 4          NaN       NaN          NaN       NaN          NaN  0.55512
#
#    Unnamed: 32
# 0      0.38709
# 1      0.40656
# 2      0.42556
# 3      0.42231
# 4      0.40570
#
# [5 rows x 33 columns]
# Tracking data home:
# Index(['Period', 'Frame', 'Time [s]', 'Player11', 'Unnamed: 4', 'Player1',
#        'Unnamed: 6', 'Player2', 'Unnamed: 8', 'Player3', 'Unnamed: 10',
#        'Player4', 'Unnamed: 12', 'Player5', 'Unnamed: 14', 'Player6',
#        'Unnamed: 16', 'Player7', 'Unnamed: 18', 'Player8', 'Unnamed: 20',
#        'Player9', 'Unnamed: 22', 'Player10', 'Unnamed: 24', 'Player12',
#        'Unnamed: 26', 'Player13', 'Unnamed: 28', 'Player14', 'Unnamed: 30',
#        'Ball', 'Unnamed: 32'],
#       dtype='object')
#    Period  Frame  Time [s]  Player11  Unnamed: 4  Player1  Unnamed: 6  \
# 0       1      1      0.04   0.00082     0.48238  0.32648     0.65322
# 1       1      2      0.08   0.00096     0.48238  0.32648     0.65322
# 2       1      3      0.12   0.00114     0.48238  0.32648     0.65322
# 3       1      4      0.16   0.00121     0.48238  0.32622     0.65317
# 4       1      5      0.20   0.00129     0.48238  0.32597     0.65269
#
#    Player2  Unnamed: 8  Player3  ...  Player10  Unnamed: 24  Player12  \
# 0  0.33701     0.48863  0.30927  ...   0.55243      0.43269       NaN
# 1  0.33701     0.48863  0.30927  ...   0.55243      0.43269       NaN
# 2  0.33701     0.48863  0.30927  ...   0.55243      0.43269       NaN
# 3  0.33687     0.48988  0.30944  ...   0.55236      0.43313       NaN
# 4  0.33664     0.49018  0.30948  ...   0.55202      0.43311       NaN
#
#    Unnamed: 26  Player13  Unnamed: 28  Player14  Unnamed: 30     Ball  \
# 0          NaN       NaN          NaN       NaN          NaN  0.45472
# 1          NaN       NaN          NaN       NaN          NaN  0.49645
# 2          NaN       NaN          NaN       NaN          NaN  0.53716
# 3          NaN       NaN          NaN       NaN          NaN  0.55346
# 4          NaN       NaN          NaN       NaN          NaN  0.55512
#
#    Unnamed: 32
# 0      0.38709
# 1      0.40656
# 2      0.42556
# 3      0.42231
# 4      0.40570
#
# [5 rows x 33 columns]

# %%
def reshape_tracking(df, team_label):
    long_rows = []
    for col in df.columns:
        if col.startswith("Player"):
            x_col = col
            y_col = f"Unnamed: {int(df.columns.get_loc(col)) + 1}"
            for _, row in df.iterrows():
                long_rows.append({
                    "Time [s]": row["Time [s]"],
                    "Frame": row["Frame"],
                    "Team": team_label.capitalize(),
                    "Player": f"{team_label.capitalize()}_{col}",
                    "X": row[x_col],
                    "Y": row[y_col]
                })
    return pd.DataFrame(long_rows)

tracking_long_home_df = reshape_tracking(tracking_data_home_df, "home")
tracking_long_away_df = reshape_tracking(tracking_data_away_df, "away")
tracking_long_df = pd.concat([tracking_long_home_df, tracking_long_away_df])
tracking_long_df.head()
# Out:
#    Time [s]  Frame  Team         Player        X        Y
# 0      0.04    1.0  Home  Home_Player11  0.00082  0.48238
# 1      0.08    2.0  Home  Home_Player11  0.00096  0.48238
# 2      0.12    3.0  Home  Home_Player11  0.00114  0.48238
# 3      0.16    4.0  Home  Home_Player11  0.00121  0.48238
# 4      0.20    5.0  Home  Home_Player11  0.00129  0.48238

# %%
# add grid position to tracking long
import helpers
tracking_long_df['Grid Position'] = tracking_long_df.apply(lambda row: helpers.get_field_position(row['X'], row['Y']), axis=1)
tracking_long_df.head()
# Out:
#    Time [s]  Frame  Team         Player        X        Y Grid Position
# 0      0.04    1.0  Home  Home_Player11  0.00082  0.48238            A5
# 1      0.08    2.0  Home  Home_Player11  0.00096  0.48238            A5
# 2      0.12    3.0  Home  Home_Player11  0.00114  0.48238            A5
# 3      0.16    4.0  Home  Home_Player11  0.00121  0.48238            A5
# 4      0.20    5.0  Home  Home_Player11  0.00129  0.48238            A5

# %%
# identify only events when grid position of player changes
def get_grid_change_events(tracking_df):
    tracking_df = tracking_df.sort_values(by=['Player', 'Time [s]'])
    tracking_df['Prev Grid Position'] = tracking_df.groupby('Player')['Grid Position'].shift(1)
    grid_change_events = tracking_df[tracking_df['Grid Position'] != tracking_df['Prev Grid Position']]
    return grid_change_events

tracking_grid_change_events_df = get_grid_change_events(tracking_long_df)
display(tracking_grid_change_events_df.head())
# Out:
#         Time [s]  Frame  Team         Player        X        Y Grid Position  \
# 145006      0.04    1.0  Away  Away_Player15  0.58393  0.20794            F3
# 145029      0.96   24.0  Away  Away_Player15  0.56821  0.19967            F2
# 145084      3.16   79.0  Away  Away_Player15  0.54274  0.20009            F3
# 145160      6.20  155.0  Away  Away_Player15  0.54714  0.30046            F4
# 145223      8.72  218.0  Away  Away_Player15  0.50298  0.40046            F5
#
#        Prev Grid Position
# 145006                NaN
# 145029                 F3
# 145084                 F2
# 145160                 F3
# 145223                 F4

# %%
# format dataframe for ocel
def format_ocel_df(tracking_df):
    ocel_df = tracking_df.copy()
    ocel_df['concept:name'] = f"Player enters"
    ocel_df['case:concept:name'] = ocel_df['Team']
    ocel_df['time:timestamp'] = pd.to_datetime(ocel_df['Time [s]'], unit='s')
    ocel_df['ocel:type:player'] = ocel_df['Player']
    ocel_df['ocel:type:team'] = ocel_df['Team']
    ocel_df['ocel:type:gridpos'] = ocel_df['Grid Position'] # @Vito: Lets also add gridpos as object
    ocel_df['ocel:eid'] = ocel_df.index.astype(str)
    
    return ocel_df

ocel_df = format_ocel_df(tracking_grid_change_events_df)
ocel_df
# Out:
#          Time [s]     Frame  Team         Player        X        Y  \
# 145006       0.04       1.0  Away  Away_Player15  0.58393  0.20794
# 145029       0.96      24.0  Away  Away_Player15  0.56821  0.19967
# 145084       3.16      79.0  Away  Away_Player15  0.54274  0.20009
# 145160       6.20     155.0  Away  Away_Player15  0.54714  0.30046
# 145223       8.72     218.0  Away  Away_Player15  0.50298  0.40046
# ...           ...       ...   ...            ...      ...      ...
# 1449618   5782.60  144565.0  Home   Home_Player9  0.11281  0.79993
# 1449630   5783.08  144577.0  Home   Home_Player9  0.11286  0.80001
# 1449730   5787.08  144677.0  Home   Home_Player9  0.11225  0.79987
# 1449802   5789.96  144749.0  Home   Home_Player9  0.11105  0.80019
# 1449992   5797.56  144939.0  Home   Home_Player9  0.14646  0.79993
#
#         Grid Position Prev Grid Position   concept:name case:concept:name  \
# 145006             F3                NaN  Player enters              Away
# 145029             F2                 F3  Player enters              Away
# 145084             F3                 F2  Player enters              Away
# 145160             F4                 F3  Player enters              Away
# 145223             F5                 F4  Player enters              Away
# ...               ...                ...            ...               ...
# 1449618            B8                 B9  Player enters              Home
# 1449630            B9                 B8  Player enters              Home
# 1449730            B8                 B9  Player enters              Home
# 1449802            B9                 B8  Player enters              Home
# 1449992            B8                 B9  Player enters              Home
#
#                  time:timestamp ocel:type:player ocel:type:team  \
# 145006  1970-01-01 00:00:00.040    Away_Player15           Away
# 145029  1970-01-01 00:00:00.960    Away_Player15           Away
# 145084  1970-01-01 00:00:03.160    Away_Player15           Away
# 145160  1970-01-01 00:00:06.200    Away_Player15           Away
# 145223  1970-01-01 00:00:08.720    Away_Player15           Away
# ...                         ...              ...            ...
# 1449618 1970-01-01 01:36:22.600     Home_Player9           Home
# 1449630 1970-01-01 01:36:23.080     Home_Player9           Home
# 1449730 1970-01-01 01:36:27.080     Home_Player9           Home
# 1449802 1970-01-01 01:36:29.960     Home_Player9           Home
# 1449992 1970-01-01 01:36:37.560     Home_Player9           Home
#
#         ocel:type:gridpos ocel:eid
# 145006                 F3   145006
# 145029                 F2   145029
# 145084                 F3   145084
# 145160                 F4   145160
# 145223                 F5   145223
# ...                   ...      ...
# 1449618                B8  1449618
# 1449630                B9  1449630
# 1449730                B8  1449730
# 1449802                B9  1449802
# 1449992                B8  1449992
#
# [902378 rows x 15 columns]

# %%
from pm4py.objects.ocel.util.log_ocel import from_traditional_pandas as pd_to_ocel

# %%
parameters = {
    "activity_key": "concept:name",
    "timestamp_key": "time:timestamp",
    "case_id_key": "case:concept:name",
    "target_object_type": "Team",
    "case_attribute_prefix": "attribute:",
    "ocel:eid": "ocel:eid"
}

ocel=pd_to_ocel(ocel_df, parameters=parameters)
# Out:
# c:\Users\Lennart\Tools\Miniconda\envs\object_centric_soccer\Lib\site-packages\pm4py\objects\ocel\util\log_ocel.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   relations[ocel_constants.DEFAULT_OBJECT_TYPE] = target_object_type

# %%
ocel.get_extended_table()
# Out:
#         ocel:eid          ocel:timestamp ocel:type:team ocel:type:gridpos  \
# 0             E0 1970-01-01 00:00:00.040           Away                J5
# 1             E0 1970-01-01 00:00:00.040           Home                A5
# 2       E1015042 1970-01-01 00:00:00.040           Away                F5
# 3       E1015042 1970-01-01 00:00:00.040           Home                D4
# 4       E1160048 1970-01-01 00:00:00.040           Away               F10
# ...          ...                     ...            ...               ...
# 902373  E1305053 1970-01-01 01:36:40.240           Away              None
# 902374  E1595065 1970-01-01 01:36:40.240           Away              None
# 902375  E1595065 1970-01-01 01:36:40.240           Home              None
# 902376   E290011 1970-01-01 01:36:40.240           Home              None
# 902377   E870035 1970-01-01 01:36:40.240           Away              None
#
#        ocel:type:player     Frame         Player  ocel:activity        Y  \
# 0         Away_Player25       1.0  Away_Player25  Player enters  0.47462
# 1         Home_Player11       1.0  Home_Player11  Player enters  0.48238
# 2         Away_Player21       1.0  Away_Player21  Player enters  0.43269
# 3          Home_Player7       1.0   Home_Player7  Player enters  0.32550
# 4         Away_Player22       1.0  Away_Player22  Player enters  0.94322
# ...                 ...       ...            ...            ...      ...
# 902373    Away_Player22  145006.0  Away_Player22  Player enters      NaN
# 902374    Away_Player24  145006.0  Away_Player24  Player enters      NaN
# 902375    Home_Player10  145006.0  Home_Player10  Player enters      NaN
# 902376     Home_Player1  145006.0   Home_Player1  Player enters      NaN
# 902377    Away_Player19  145006.0  Away_Player19  Player enters      NaN
#
#         Team  Time [s] Prev Grid Position        X Grid Position  \
# 0       Away      0.04                NaN  0.90509            J5
# 1       Home      0.04                NaN  0.00082            A5
# 2       Away      0.04                NaN  0.55243            F5
# 3       Home      0.04                NaN  0.39125            D4
# 4       Away      0.04                NaN  0.50067           F10
# ...      ...       ...                ...      ...           ...
# 902373  Away   5800.24               None      NaN          None
# 902374  Away   5800.24               None      NaN          None
# 902375  Home   5800.24               None      NaN          None
# 902376  Home   5800.24               None      NaN          None
# 902377  Away   5800.24               None      NaN          None
#
#        ocel:type:Team
# 0        [Away, Home]
# 1        [Away, Home]
# 2        [Away, Home]
# 3        [Away, Home]
# 4        [Away, Home]
# ...               ...
# 902373         [Away]
# 902374   [Away, Home]
# 902375   [Away, Home]
# 902376         [Home]
# 902377         [Away]
#
# [902378 rows x 15 columns]

# %%
path = "tracking_game1.jsonocel"
pm4py.write_ocel(ocel, path)
# Out:
# c:\Users\Lennart\Tools\Miniconda\envs\object_centric_soccer\Lib\site-packages\pm4py\objects\ocel\util\ocel_consistency.py:115: UserWarning: The event identifiers in the OCEL are not unique!
#   warnings.warn("The event identifiers in the OCEL are not unique!")
